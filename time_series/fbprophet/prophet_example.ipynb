# %%
import pandas as pd
import numpy as np
from fbprophet import Prophet

# %%
df = pd.read_csv('examples/example_wp_peyton_manning.csv')
df['y'] = np.log(df['y'])
df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
m = Prophet()
m.fit(df)

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.200900    7.485857    8.879232
# 3266 2017-01-16  8.525905    7.816301    9.220060
# 3267 2017-01-17  8.313265    7.618106    9.048656
# 3268 2017-01-18  8.145861    7.428212    8.857422
# 3269 2017-01-19  8.157749    7.464210    8.934053

# %%
m.plot(forecast)

# %%
m.plot_components(forecast)

# %%
m.changepoints
# Out:
# 93     2008-03-17
# 186    2008-06-20
# 279    2008-10-11
# 372    2009-01-14
# 465    2009-04-17
# 558    2009-07-19
# 651    2009-10-27
# 744    2010-02-01
# 837    2010-05-07
# 930    2010-08-15
# 1023   2010-11-16
# 1116   2011-02-17
# 1208   2011-05-20
# 1301   2011-08-21
# 1394   2011-11-24
# 1487   2012-02-27
# 1580   2012-05-31
# 1673   2012-09-01
# 1766   2012-12-03
# 1859   2013-03-06
# 1952   2013-06-07
# 2045   2013-09-09
# 2138   2013-12-11
# 2231   2014-03-15
# 2324   2014-06-16
# Name: ds, dtype: datetime64[ns]
