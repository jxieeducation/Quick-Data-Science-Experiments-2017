# %%
from IPython.display import Image

# %%
Image("data_aggregation.png")

# %% [markdown]
# * ** look at what the different metrics mean**
# * note: I can prob discretize the win price stats like this as well!!!!

# %% [markdown]
# ### stock splits
# * do it when prices are too high, to make it more liquid
# * adjusted close: adjust the stock splits, so we don't get tricked

# %% [markdown]
# ### dividends
# * e.g. 100 dollar stock, dividends 1 dollar per year
# * company value on the date before dividend is 100 + 1, and 100 afterwards

# %% [markdown]
# ### survivorship bias
# * if we backtest, it's biased because we are selecting stocks that we knew survived until now!
# * **note** use unbiased data
