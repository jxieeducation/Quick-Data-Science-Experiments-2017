# %%
from __future__ import print_function

import tensorflow as tf
from tensorflow.contrib import rnn

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# Training Parameters
learning_rate = 0.001
training_steps = 10000
batch_size = 128
display_step = 200

# Network Parameters
num_input = 28 # MNIST data input (img shape: 28*28)
timesteps = 28 # timesteps
num_hidden = 128 # hidden layer num of features
num_classes = 10 # MNIST total classes (0-9 digits)

# tf Graph input
X = tf.placeholder("float", [None, timesteps, num_input])
Y = tf.placeholder("float", [None, num_classes])

# %%
# Define weights
weights = {
    'out': tf.Variable(tf.random_normal([num_hidden, num_classes]))
}
biases = {
    'out': tf.Variable(tf.random_normal([num_classes]))
}

# %%
def RNN(x, weights, biases):

    # Prepare data shape to match `rnn` function requirements
    # Current data input shape: (batch_size, timesteps, n_input)
    # Required shape: 'timesteps' tensors list of shape (batch_size, n_input)

    # Unstack to get a list of 'timesteps' tensors of shape (batch_size, n_input)
    x = tf.unstack(x, timesteps, 1)

    # Define a lstm cell with tensorflow
    lstm_cell = rnn.BasicLSTMCell(num_hidden, forget_bias=1.0)

    # Get lstm cell output
    outputs, states = rnn.static_rnn(lstm_cell, x, dtype=tf.float32)

    # Linear activation, using rnn inner loop last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

# %%
logits = RNN(X, weights, biases)
prediction = tf.nn.softmax(logits)

# Define loss and optimizer
loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
    logits=logits, labels=Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)

# Evaluate model (with test logits, for dropout to be disabled)
correct_pred = tf.equal(tf.argmax(prediction, 1), tf.argmax(Y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

# %%
# Start training
with tf.Session() as sess:

    # Run the initializer
    sess.run(init)

    for step in range(1, training_steps+1):
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Reshape data to get 28 seq of 28 elements
        batch_x = batch_x.reshape((batch_size, timesteps, num_input))
        # Run optimization op (backprop)
        sess.run(train_op, feed_dict={X: batch_x, Y: batch_y})
        if step % display_step == 0 or step == 1:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([loss_op, accuracy], feed_dict={X: batch_x,
                                                                 Y: batch_y})
            print("Step " + str(step) + ", Minibatch Loss= " + \
                  "{:.4f}".format(loss) + ", Training Accuracy= " + \
                  "{:.3f}".format(acc))

    print("Optimization Finished!")

    # Calculate accuracy for 128 mnist test images
    test_len = 128
    test_data = mnist.test.images[:test_len].reshape((-1, timesteps, num_input))
    test_label = mnist.test.labels[:test_len]
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={X: test_data, Y: test_label}))
# Out:
# Step 1, Minibatch Loss= 2.5680, Training Accuracy= 0.102
# Step 200, Minibatch Loss= 2.0759, Training Accuracy= 0.352
# Step 400, Minibatch Loss= 1.9197, Training Accuracy= 0.391
# Step 600, Minibatch Loss= 1.8382, Training Accuracy= 0.477
# Step 800, Minibatch Loss= 1.6930, Training Accuracy= 0.477
# Step 1000, Minibatch Loss= 1.7677, Training Accuracy= 0.398
# Step 1200, Minibatch Loss= 1.4508, Training Accuracy= 0.625
# Step 1400, Minibatch Loss= 1.4764, Training Accuracy= 0.539
# Step 1600, Minibatch Loss= 1.3669, Training Accuracy= 0.570
# Step 1800, Minibatch Loss= 1.2508, Training Accuracy= 0.648
# Step 2000, Minibatch Loss= 1.2077, Training Accuracy= 0.664
# Step 2200, Minibatch Loss= 1.2498, Training Accuracy= 0.602
# Step 2400, Minibatch Loss= 1.2030, Training Accuracy= 0.641
# Step 2600, Minibatch Loss= 1.2047, Training Accuracy= 0.602
# Step 2800, Minibatch Loss= 0.9310, Training Accuracy= 0.703
# Step 3000, Minibatch Loss= 1.0564, Training Accuracy= 0.641
# Step 3200, Minibatch Loss= 1.0020, Training Accuracy= 0.672
# Step 3400, Minibatch Loss= 0.9683, Training Accuracy= 0.641
# Step 3600, Minibatch Loss= 0.8312, Training Accuracy= 0.758
# Step 3800, Minibatch Loss= 1.0619, Training Accuracy= 0.648
# Step 4000, Minibatch Loss= 0.9585, Training Accuracy= 0.680
# Step 4200, Minibatch Loss= 0.9751, Training Accuracy= 0.734
# Step 4400, Minibatch Loss= 0.7743, Training Accuracy= 0.789
# Step 4600, Minibatch Loss= 0.7392, Training Accuracy= 0.852
# Step 4800, Minibatch Loss= 0.8615, Training Accuracy= 0.758
# Step 5000, Minibatch Loss= 0.8856, Training Accuracy= 0.750
# Step 5200, Minibatch Loss= 0.7346, Training Accuracy= 0.797
# Step 5400, Minibatch Loss= 0.6938, Training Accuracy= 0.773
# Step 5600, Minibatch Loss= 0.8107, Training Accuracy= 0.766
# Step 5800, Minibatch Loss= 0.7763, Training Accuracy= 0.750
# Step 6000, Minibatch Loss= 0.7039, Training Accuracy= 0.797
# Step 6200, Minibatch Loss= 0.5321, Training Accuracy= 0.844
# Step 6400, Minibatch Loss= 0.7205, Training Accuracy= 0.781
# Step 6600, Minibatch Loss= 0.6526, Training Accuracy= 0.820
# Step 6800, Minibatch Loss= 0.6795, Training Accuracy= 0.828
# Step 7000, Minibatch Loss= 0.6257, Training Accuracy= 0.836
# Step 7200, Minibatch Loss= 0.6014, Training Accuracy= 0.820
# Step 7400, Minibatch Loss= 0.5319, Training Accuracy= 0.844
# Step 7600, Minibatch Loss= 0.6141, Training Accuracy= 0.852
# Step 7800, Minibatch Loss= 0.7392, Training Accuracy= 0.781
# Step 8000, Minibatch Loss= 0.5050, Training Accuracy= 0.875
# Step 8200, Minibatch Loss= 0.5140, Training Accuracy= 0.812
# Step 8400, Minibatch Loss= 0.5113, Training Accuracy= 0.820
# Step 8600, Minibatch Loss= 0.5284, Training Accuracy= 0.805
# Step 8800, Minibatch Loss= 0.4881, Training Accuracy= 0.859
# Step 9000, Minibatch Loss= 0.5184, Training Accuracy= 0.844
# Step 9200, Minibatch Loss= 0.4038, Training Accuracy= 0.906
# Step 9400, Minibatch Loss= 0.4916, Training Accuracy= 0.836
# Step 9600, Minibatch Loss= 0.5153, Training Accuracy= 0.844
# Step 9800, Minibatch Loss= 0.5205, Training Accuracy= 0.836
# Step 10000, Minibatch Loss= 0.4228, Training Accuracy= 0.867
# Optimization Finished!
# Testing Accuracy: 0.882812
