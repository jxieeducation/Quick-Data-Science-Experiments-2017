# %% [markdown]
# [src](https://blog.sicara.com/keras-tutorial-content-based-image-retrieval-convolutional-denoising-autoencoder-dc91450cc511)

# %% [markdown]
# ### denoising conv autoencoder
# * noisy input to output

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, ZeroPadding2D
from keras.models import Model
from keras.callbacks import TensorBoard
from keras.datasets import mnist
import numpy as np


(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))  # adapt this if using `channels_first` image data format
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))  # adapt this if using `channels_first` image data format

# %%
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %%
def train_model():
    input_img = Input(shape=(28, 28, 1))  # adapt this if using `channels_first` image data format
    x = Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
    x = MaxPooling2D((2, 2), padding='same')(x)
    x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2), padding='same')(x)
    x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
    encoded = MaxPooling2D((2, 2), padding='same', name='encoder')(x)

    # at this point the representation is (4, 4, 8) i.e. 128-dimensional

    x = Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
    x = UpSampling2D((2, 2))(x)
    x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
    x = UpSampling2D((2, 2))(x)
    x = Conv2D(16, (3, 3), activation='relu')(x)
    x = UpSampling2D((2, 2))(x)
    decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

    autoencoder = Model(input_img, decoded)
    autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

    autoencoder.fit(x_train_noisy, x_train,
                    epochs=1,
                    batch_size=128,
                    shuffle=True,
                    validation_data=(x_test_noisy, x_test),
                    callbacks=[TensorBoard(log_dir='/tmp/tb', histogram_freq=0, write_graph=False)])

    autoencoder.save('autoencoder.h5')
train_model()
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 79s - loss: 0.2827 - val_loss: 0.2296

# %%
from keras.models import load_model
from sklearn.metrics import label_ranking_average_precision_score
import cv2

autoencoder = load_model('autoencoder.h5')

def plot_denoised_images():
    denoised_images = autoencoder.predict(x_test_noisy.reshape(x_test_noisy.shape[0], x_test_noisy.shape[1], x_test_noisy.shape[2], 1))
    test_img = x_test_noisy[0]
    resized_test_img = cv2.resize(test_img, (280, 280))
    cv2.imshow('input', resized_test_img)
#     cv2.waitKey(0)
    output = denoised_images[0]
    resized_output = cv2.resize(output, (280, 280))
    cv2.imshow('output', resized_output)
#     cv2.waitKey(0)

plot_denoised_images()

# %%
autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 8)         1160
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 8)           0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 8)           584
# _________________________________________________________________
# encoder (MaxPooling2D)       (None, 4, 4, 8)           0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 8)           584
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 8, 8, 8)           0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 8)           584
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 16)        1168
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 1)         145
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.get_config()
# Out:
# {'input_layers': [[u'input_1', 0, 0]],
#  'layers': [{'class_name': 'InputLayer',
#    'config': {'batch_input_shape': (None, 28, 28, 1),
#     'dtype': u'float32',
#     'name': u'input_1',
#     'sparse': False},
#    'inbound_nodes': [],
#    'name': u'input_1'},
#   {'class_name': 'Conv2D',
#    'config': {'activation': 'relu',
#     'activity_regularizer': None,
#     'bias_constraint': None,
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'bias_regularizer': None,
#     'data_format': u'channels_last',
#     'dilation_rate': (1, 1),
#     'filters': 16,
#     'kernel_constraint': None,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'distribution': u'uniform',
#       'mode': u'fan_avg',
#       'scale': 1.0,
#       'seed': None}},
#     'kernel_regularizer': None,
#     'kernel_size': (3, 3),
#     'name': u'conv2d_1',
#     'padding': u'same',
#     'strides': (1, 1),
#     'trainable': True,
#     'use_bias': True},
#    'inbound_nodes': [[[u'input_1', 0, 0, {}]]],
#    'name': u'conv2d_1'},
#   {'class_name': 'MaxPooling2D',
#    'config': {'data_format': u'channels_last',
#     'name': u'max_pooling2d_1',
#     'padding': u'same',
#     'pool_size': (2, 2),
#     'strides': (2, 2),
#     'trainable': True},
#    'inbound_nodes': [[[u'conv2d_1', 0, 0, {}]]],
#    'name': u'max_pooling2d_1'},
#   {'class_name': 'Conv2D',
#    'config': {'activation': 'relu',
#     'activity_regularizer': None,
#     'bias_constraint': None,
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'bias_regularizer': None,
#     'data_format': u'channels_last',
#     'dilation_rate': (1, 1),
#     'filters': 8,
#     'kernel_constraint': None,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'distribution': u'uniform',
#       'mode': u'fan_avg',
#       'scale': 1.0,
#       'seed': None}},
#     'kernel_regularizer': None,
#     'kernel_size': (3, 3),
#     'name': u'conv2d_2',
#     'padding': u'same',
#     'strides': (1, 1),
#     'trainable': True,
#     'use_bias': True},
#    'inbound_nodes': [[[u'max_pooling2d_1', 0, 0, {}]]],
#    'name': u'conv2d_2'},
#   {'class_name': 'MaxPooling2D',
#    'config': {'data_format': u'channels_last',
#     'name': u'max_pooling2d_2',
#     'padding': u'same',
#     'pool_size': (2, 2),
#     'strides': (2, 2),
#     'trainable': True},
#    'inbound_nodes': [[[u'conv2d_2', 0, 0, {}]]],
#    'name': u'max_pooling2d_2'},
#   {'class_name': 'Conv2D',
#    'config': {'activation': 'relu',
#     'activity_regularizer': None,
#     'bias_constraint': None,
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'bias_regularizer': None,
#     'data_format': u'channels_last',
#     'dilation_rate': (1, 1),
#     'filters': 8,
#     'kernel_constraint': None,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'distribution': u'uniform',
#       'mode': u'fan_avg',
#       'scale': 1.0,
#       'seed': None}},
#     'kernel_regularizer': None,
#     'kernel_size': (3, 3),
#     'name': u'conv2d_3',
#     'padding': u'same',
#     'strides': (1, 1),
#     'trainable': True,
#     'use_bias': True},
#    'inbound_nodes': [[[u'max_pooling2d_2', 0, 0, {}]]],
#    'name': u'conv2d_3'},
#   {'class_name': 'MaxPooling2D',
#    'config': {'data_format': u'channels_last',
#     'name': u'encoder',
#     'padding': u'same',
#     'pool_size': (2, 2),
#     'strides': (2, 2),
#     'trainable': True},
#    'inbound_nodes': [[[u'conv2d_3', 0, 0, {}]]],
#    'name': u'encoder'},
#   {'class_name': 'Conv2D',
#    'config': {'activation': 'relu',
#     'activity_regularizer': None,
#     'bias_constraint': None,
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'bias_regularizer': None,
#     'data_format': u'channels_last',
#     'dilation_rate': (1, 1),
#     'filters': 8,
#     'kernel_constraint': None,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'distribution': u'uniform',
#       'mode': u'fan_avg',
#       'scale': 1.0,
#       'seed': None}},
#     'kernel_regularizer': None,
#     'kernel_size': (3, 3),
#     'name': u'conv2d_4',
#     'padding': u'same',
#     'strides': (1, 1),
#     'trainable': True,
#     'use_bias': True},
#    'inbound_nodes': [[[u'encoder', 0, 0, {}]]],
#    'name': u'conv2d_4'},
#   {'class_name': 'UpSampling2D',
#    'config': {'data_format': u'channels_last',
#     'name': u'up_sampling2d_1',
#     'size': (2, 2),
#     'trainable': True},
#    'inbound_nodes': [[[u'conv2d_4', 0, 0, {}]]],
#    'name': u'up_sampling2d_1'},
#   {'class_name': 'Conv2D',
#    'config': {'activation': 'relu',
#     'activity_regularizer': None,
#     'bias_constraint': None,
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'bias_regularizer': None,
#     'data_format': u'channels_last',
#     'dilation_rate': (1, 1),
#     'filters': 8,
#     'kernel_constraint': None,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'distribution': u'uniform',
#       'mode': u'fan_avg',
#       'scale': 1.0,
#       'seed': None}},
#     'kernel_regularizer': None,
#     'kernel_size': (3, 3),
#     'name': u'conv2d_5',
#     'padding': u'same',
#     'strides': (1, 1),
#     'trainable': True,
#     'use_bias': True},
#    'inbound_nodes': [[[u'up_sampling2d_1', 0, 0, {}]]],
#    'name': u'conv2d_5'},
#   {'class_name': 'UpSampling2D',
#    'config': {'data_format': u'channels_last',
#     'name': u'up_sampling2d_2',
#     'size': (2, 2),
#     'trainable': True},
#    'inbound_nodes': [[[u'conv2d_5', 0, 0, {}]]],
#    'name': u'up_sampling2d_2'},
#   {'class_name': 'Conv2D',
#    'config': {'activation': 'relu',
#     'activity_regularizer': None,
#     'bias_constraint': None,
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'bias_regularizer': None,
#     'data_format': u'channels_last',
#     'dilation_rate': (1, 1),
#     'filters': 16,
#     'kernel_constraint': None,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'distribution': u'uniform',
#       'mode': u'fan_avg',
#       'scale': 1.0,
#       'seed': None}},
#     'kernel_regularizer': None,
#     'kernel_size': (3, 3),
#     'name': u'conv2d_6',
#     'padding': u'valid',
#     'strides': (1, 1),
#     'trainable': True,
#     'use_bias': True},
#    'inbound_nodes': [[[u'up_sampling2d_2', 0, 0, {}]]],
#    'name': u'conv2d_6'},
#   {'class_name': 'UpSampling2D',
#    'config': {'data_format': u'channels_last',
#     'name': u'up_sampling2d_3',
#     'size': (2, 2),
#     'trainable': True},
#    'inbound_nodes': [[[u'conv2d_6', 0, 0, {}]]],
#    'name': u'up_sampling2d_3'},
#   {'class_name': 'Conv2D',
#    'config': {'activation': 'sigmoid',
#     'activity_regularizer': None,
#     'bias_constraint': None,
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'bias_regularizer': None,
#     'data_format': u'channels_last',
#     'dilation_rate': (1, 1),
#     'filters': 1,
#     'kernel_constraint': None,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'distribution': u'uniform',
#       'mode': u'fan_avg',
#       'scale': 1.0,
#       'seed': None}},
#     'kernel_regularizer': None,
#     'kernel_size': (3, 3),
#     'name': u'conv2d_7',
#     'padding': u'same',
#     'strides': (1, 1),
#     'trainable': True,
#     'use_bias': True},
#    'inbound_nodes': [[[u'up_sampling2d_3', 0, 0, {}]]],
#    'name': u'conv2d_7'}],
#  'name': u'model_1',
#  'output_layers': [[u'conv2d_7', 0, 0]]}
